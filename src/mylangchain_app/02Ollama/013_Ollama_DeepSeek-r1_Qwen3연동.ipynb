# %% [markdown]
# #### 1. 패키지 설치

# %%
# portry langchain langchain-ollama langgraph

# %% [markdown]
# #### 로컬 Ollama로 설치한 deepseek-r1 모델과 ExaOne3 또는 Qwen2.5 모델을 사용하기
# ##### ollama run deepseek-r1:7b
# ##### ollama run exaone3.5
# ##### ollama run qwen2.5:1.5b

# %% [markdown]
# ##### 최신버전 LangChain에서는 ChatOllama와 RunnableSequence(prompt | llm) 를 사용

# %% [markdown]
# ##### deepseeek 모델 9.9 와 9.11 크기 비교문제  (영어로 질문, invoke()함수)

# %%
import requests

response = requests.get("http://127.0.0.1:11434")
print(response.text)
# Out:
# Ollama is running

# %%
from langchain_ollama import ChatOllama

try:
    deepseek = ChatOllama(model="deepseek-r1:1.5b", temperature=0.5)    # 모델 호출
    response = deepseek.invoke("which is bigger between 9.9 and 9.11?")
    print(response.content)
except Exception as e:
    print(f"Error: {e}")

# %% [markdown]
# ##### qwen3:1.7b 모델 9.9 와 9.11 크기 비교문제  (한글로 질문, invoke()함수)

# %%
from langchain_ollama import ChatOllama

try:
    #exaone = ChatOllama(model="exaone3.5:2.4b", temperature=0.5, n_gpu_layers=0, batch_size=128)
    qwen = ChatOllama(model="qwen3:1.7b", temperature=0.5)
    # 모델 호출
    response = qwen.invoke("9.9와 9.11 중 무엇이 더 큰가요?")
    print(response.content)
except Exception as e:
    print(f"Error: {e}")
# Out:
# <think>
# Okay, let's see. The user is asking which is bigger between 9.9 and 9.11. Hmm. Both numbers are decimals. Let me think about how to compare them.
#
# First, I know that when comparing decimals, you start from the leftmost digit. So, both numbers have the same integer part, which is 9. Then, the next digit after the decimal is the tenths place. For 9.9, the tenths digit is 9, and for 9.11, the tenths digit is 1. Wait, so 9.9 has a 9 in the tenths place, while 9.11 has a 1. That means 9.9 is larger than 9.11 because the tenths digit is higher.
#
# But wait, let me double-check. The numbers are 9.9 and 9.11. If I write them out, 9.9 is 9 and 9 tenths, which is 9.90. And 9.11 is 9 and 11 hundredths. So, 9.90 is larger than 9.11 because 9.90 is 9.90 and 9.11 is 9.11. The tenths place in 9.90 is 9, which is more than 1 in the tenths place of 9.11. So yeah, 9.9 is bigger.
#
# I guess that's the straightforward way. But maybe I should consider if there's any trick here. Like, maybe the user is confused about the decimal places. But no, 9.9 is two decimal places, but since the tenths place is 9, which is more than 1, so it's definitely larger.
#
# Another way to think is to subtract them. 9.9 minus 9.11 equals 0.79. So, 9.9 is 0.79 more than 9.11. That confirms it. So, the answer is 9.9 is bigger.
# </think>
#
# 9.9는 9.11보다 더 큰 수입니다.
# **증명**:
# - 9.9는 9.90으로, 9.11은 9.11로 비교할 때, 소수점 첫 번째 자리에서 9 > 1이므로 9.9가 더 큰 수입니다.
# - 9.9 - 9.11 = 0.79로, 9.9이 9.11보다 0.79 더 큰 수입니다.
#
# **답변**: 9.9가 더 큰 수입니다.

# %% [markdown]
# ##### deepseeek 모델 9.9 와 9.11 크기 비교문제  (영어로 질문, stream()함수)

# %%
from IPython.display import display, Markdown
from langchain_ollama import ChatOllama

deepseek = ChatOllama(model="deepseek-r1:1.5b", temperature=0.5)

answer = []
for chunk in deepseek.stream("which is bigger between 9.9 and 9.11?"):
    answer.append(chunk.content)
    print(chunk.content, end="", flush=True)
# Out:
# <think>
# To determine which number is larger, I'll start by comparing the whole number parts of both numbers.
#
# Both numbers have a whole number part of 9, so they are equal in that aspect.
#
# Next, I'll look at the decimal parts. The first number has 0.9, while the second number has 0.11.
#
# To make an accurate comparison, I can convert both decimals to thousandths:
#
# - 0.9 is equivalent to 0.900.
# - 0.11 remains as it is at 0.11.
#
# Now, comparing the thousandth parts:
# - 0.900 has a 9 in the thousandth place.
# - 0.11 has an 1 in the hundredth place.
#
# Since 9 is greater than 1, 0.900 is larger than 0.11.
#
# Therefore, 9.9 is bigger than 9.11.
# </think>
#
# To determine which number is larger between **9.9** and **9.11**, let's break it down step by step:
#
# 1. **Compare the Whole Numbers:**
#    - Both numbers have the same whole number part, which is **9**.
#
# 2. **Compare the Decimal Parts:**
#    - For **9.9**: The decimal part is **0.9**.
#    - For **9.11**: The decimal part is **0.11**.
#
# 3. **Convert to Thousandths for Comparison:**
#    - **9.9** can be written as **9.90** (since adding a zero doesn't change its value).
#    - **0.90** is equivalent to **0.900**.
#    - **0.11** remains the same.
#
# 4. **Compare the Thousandths Place:**
#    - **0.900** has a **9** in the thousandths place.
#    - **0.11** has an **1** in the hundredths place, which is equivalent to **0.01** in the thousandths place.
#
# 5. **Conclusion:**
#    - Since **9 > 1**, **0.900** (or **9.9**) is greater than **0.11** (or **9.11**).
#
# Therefore,
#
# \[
# \boxed{9.9 \text{ is larger than } 9.11}
# \]

# %%
answer_md=''.join([i for i in answer])
display(Markdown(answer_md))

# %% [markdown]
# ##### deepseeek 모델 9.9 와 9.11 크기 비교문제  (한글로 질문, stream()함수)

# %%
from IPython.display import display, Markdown
from langchain_ollama import ChatOllama

deepseek = ChatOllama(model="deepseek-r1:1.5b", temperature=0.5)

answer = []
for chunk in deepseek.stream("9.9와 9.11 중 무엇이 더 큰가요?"):
    answer.append(chunk.content)
    print(chunk.content, end="", flush=True)

answer_md=''.join([i for i in answer])
display(Markdown(answer_md))
# Out:
# <think>
# First, I need to compare the decimal numbers 9.9 and 9.11.
#
# Both numbers have the same whole number part, which is 9.
#
# To make a fair comparison, I'll add a zero to 9.9, making it 9.90. Now both numbers have two decimal places.
#
# Next, I'll compare each digit from left to right after the decimal point.
# The first digit after the decimal is 9 for both numbers, so they are equal there.
#
# Moving to the second digit, 9 in 9.90 is greater than 1 in 9.11.
# Since one number has a larger digit at an earlier place value, it is considered greater overall.
#
# Therefore, 9.9 is greater than 9.11.
# </think>
#
#  comparison between **9.9** and **9.11**:
#
# To determine which decimal is larger between **9.9** and **9.11**, follow these steps:
#
# 1. **Equalize the Decimal Places:**
#    - Add a zero to **9.9** to make it **9.90**.
#    - Now, both numbers are:
#      - **9.90**
#      - **9.11**
#
# 2. **Compare Digit by Digit:**
#    - Compare the whole number parts: Both have **9**, so they are equal.
#    - Move to the first decimal place:
#      - **9** (from 9.90) vs. **1** (from 9.11)
#      - Since **9 > 1**, **9.90** is larger than **9.11**.
#
# 3. **Conclusion:**
#    - Therefore, **9.9** is greater than **9.11**.
#
# \boxed{9.9 \text{ > } 9.11}
# <think>
# First, I need to compare the decimal numbers 9.9 and 9.11.
#
# Both numbers have the same whole number part, which is 9.
#
# To make a fair comparison, I'll add a zero to 9.9, making it 9.90. Now both numbers have two decimal places.
#
# Next, I'll compare each digit from left to right after the decimal point.
# The first digit after the decimal is 9 for both numbers, so they are equal there.
#
# Moving to the second digit, 9 in 9.90 is greater than 1 in 9.11.
# Since one number has a larger digit at an earlier place value, it is considered greater overall.
#
# Therefore, 9.9 is greater than 9.11.
# </think>
#
#  comparison between **9.9** and **9.11**:
#
# To determine which decimal is larger between **9.9** and **9.11**, follow these steps:
#
# 1. **Equalize the Decimal Places:**
#    - Add a zero to **9.9** to make it **9.90**.
#    - Now, both numbers are:
#      - **9.90**
#      - **9.11**
#
# 2. **Compare Digit by Digit:**
#    - Compare the whole number parts: Both have **9**, so they are equal.
#    - Move to the first decimal place:
#      - **9** (from 9.90) vs. **1** (from 9.11)
#      - Since **9 > 1**, **9.90** is larger than **9.11**.
#
# 3. **Conclusion:**
#    - Therefore, **9.9** is greater than **9.11**.
#
# \boxed{9.9 \text{ > } 9.11}

# %% [markdown]
# ##### qwen3:1.7b 모델 9.9 와 9.11 크기 비교문제  (한글로 질문, stream()함수)

# %%
from langchain_ollama import ChatOllama

#model = ChatOllama(model="exaone3.5:2.4b", temperature=0.5)
model = ChatOllama(model="qwen3:1.7b:1b", temperature=0.5)

answer = []
for chunk in model.stream("9.9와 9.11 중 무엇이 더 큰가요?"):
    answer.append(chunk.content)
    print(chunk.content, end="", flush=True)

answer_md=''.join([i for i in answer])
display(Markdown(answer_md))
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[6], line 7
#       4 model = ChatOllama(model="qwen3:1.7b:1b", temperature=0.5)
#       6 answer = []
# ----> 7 for chunk in model.stream("9.9와 9.11 중 무엇이 더 큰가요?"):
#       8     answer.append(chunk.content)
#       9     print(chunk.content, end="", flush=True)
#
# File c:\Users\user\AppData\Local\pypoetry\Cache\virtualenvs\mylangchain-app-SBe-Yh6W-py3.12\Lib\site-packages\langchain_core\language_models\chat_models.py:522, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     520 input_messages = _normalize_messages(messages)
#     521 run_id = "-".join((_LC_ID_PREFIX, str(run_manager.run_id)))
# --> 522 for chunk in self._stream(input_messages, stop=stop, **kwargs):
#     523     if chunk.message.id is None:
#     524         chunk.message.id = run_id
#
# File c:\Users\user\AppData\Local\pypoetry\Cache\virtualenvs\mylangchain-app-SBe-Yh6W-py3.12\Lib\site-packages\langchain_ollama\chat_models.py:907, in ChatOllama._stream(self, messages, stop, run_manager, **kwargs)
#     900 def _stream(
#     901     self,
#     902     messages: list[BaseMessage],
#    (...)    905     **kwargs: Any,
#     906 ) -> Iterator[ChatGenerationChunk]:
# --> 907     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     908         if run_manager:
#     909             run_manager.on_llm_new_token(
#     910                 chunk.text,
#     911                 verbose=self.verbose,
#     912             )
#
# File c:\Users\user\AppData\Local\pypoetry\Cache\virtualenvs\mylangchain-app-SBe-Yh6W-py3.12\Lib\site-packages\langchain_ollama\chat_models.py:846, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#     839 def _iterate_over_stream(
#     840     self,
#     841     messages: list[BaseMessage],
#     842     stop: Optional[list[str]] = None,
#     843     **kwargs: Any,
#     844 ) -> Iterator[ChatGenerationChunk]:
#     845     reasoning = kwargs.get("reasoning", self.reasoning)
# --> 846     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     847         if not isinstance(stream_resp, str):
#     848             content = (
#     849                 stream_resp["message"]["content"]
#     850                 if "message" in stream_resp and "content" in stream_resp["message"]
#     851                 else ""
#     852             )
#
# File c:\Users\user\AppData\Local\pypoetry\Cache\virtualenvs\mylangchain-app-SBe-Yh6W-py3.12\Lib\site-packages\langchain_ollama\chat_models.py:745, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     743 if chat_params["stream"]:
#     744     if self._client:
# --> 745         yield from self._client.chat(**chat_params)
#     746 else:
#     747     if self._client:
#
# File c:\Users\user\AppData\Local\pypoetry\Cache\virtualenvs\mylangchain-app-SBe-Yh6W-py3.12\Lib\site-packages\ollama\_client.py:170, in Client._request.<locals>.inner()
#     168 except httpx.HTTPStatusError as e:
#     169   e.response.read()
# --> 170   raise ResponseError(e.response.text, e.response.status_code) from None
#     172 for line in r.iter_lines():
#     173   part = json.loads(line)
#
# ResponseError: model is required (status code: 400)

# %% [markdown]
# #### DeepSeek의 추론 능력과 qwen 한글 생성 능력 결합하기
# * DeepSeek는 태그 안에서 이루어지는 추론을 기반으로 다른 LLM 대비 높은 성능을 발휘합니다.
# * 하지만 Ollama에서 제공하는 deepseek r1-distill-qwen 모델은 한국어 생성 능력이 부족합니다.
# * DeepSeek의 추론 능력과 qwen 한글 생성 능력 결합해 보겠습니다.

# %%
from langchain_ollama import ChatOllama

reasoning_model = ChatOllama(model="deepseek-r1:1.5b", temperature=0, stop=["</think>"])
print(reasoning_model)
# Out:
# model='deepseek-r1:1.5b' temperature=0.0 stop=['</think>']

# %%
#generation_model = ChatOllama(model="exaone3.5:2.4b", temperature=0.7)
generation_model = ChatOllama(model="qwen3:1.7b", temperature=0.7)
print(generation_model)
# Out:
# model='qwen3:1.7b' temperature=0.7

# %% [markdown]
# #### LangGraph 로 연결하기

# %%
from langgraph.graph import START, StateGraph
from typing_extensions import TypedDict
from langchain_core.prompts import ChatPromptTemplate

#LangGraph에서 State 사용자정의 클래스는 노드 간의 정보를 전달하는 틀입니다. 
#노드 간에 계속 전달하고 싶거나, 그래프 내에서 유지해야 할 정보를 미리 정의힙니다. 
class State(TypedDict):
    question: str
    thinking: str
    answer: str

answer_prompt = ChatPromptTemplate([
    (
        "system",
        """
        당신은 사용자의 질문에 대해 명확하고 포괄적인 답변을 제공하는 AI 어시스턴트입니다.

        당신의 작업은 다음과 같습니다:
        - 질문과 제공된 추론을 신중하게 분석하세요.
        - 추론에서 얻은 통찰력을 포함하여 잘 구조화된 답변을 생성하세요.
        - 답변이 사용자의 질문에 직접적으로 대응하도록 하세요.
        - 정보를 명확하고 자연스럽게 전달하되, 추론 과정을 명시적으로 언급하지 마세요.

        지침:
        - 답변을 대화 형식으로 작성하고, 흥미롭게 전달하세요.
        - 중요한 포인트를 모두 다루면서도 명확하고 간결하게 작성하세요.
        - 제공된 추론을 사용한다는 것을 언급하지 말고, 그 통찰력을 자연스럽게 포함시키세요.
        - 도움이 되고 전문적인 톤을 유지하세요.

        목표: 사용자의 질문에 직접적으로 대응하면서 추론 과정에서 얻은 통찰력을 자연스럽게 포함한 정보 제공입니다.
        """
    ),
    (
        "human",
        """
        질문: {question}
        추론: {thinking}
        """
    )
])
print(answer_prompt)
# Out:
# input_variables=['question', 'thinking'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='\n        당신은 사용자의 질문에 대해 명확하고 포괄적인 답변을 제공하는 AI 어시스턴트입니다.\n\n        당신의 작업은 다음과 같습니다:\n        - 질문과 제공된 추론을 신중하게 분석하세요.\n        - 추론에서 얻은 통찰력을 포함하여 잘 구조화된 답변을 생성하세요.\n        - 답변이 사용자의 질문에 직접적으로 대응하도록 하세요.\n        - 정보를 명확하고 자연스럽게 전달하되, 추론 과정을 명시적으로 언급하지 마세요.\n\n        지침:\n        - 답변을 대화 형식으로 작성하고, 흥미롭게 전달하세요.\n        - 중요한 포인트를 모두 다루면서도 명확하고 간결하게 작성하세요.\n        - 제공된 추론을 사용한다는 것을 언급하지 말고, 그 통찰력을 자연스럽게 포함시키세요.\n        - 도움이 되고 전문적인 톤을 유지하세요.\n\n        목표: 사용자의 질문에 직접적으로 대응하면서 추론 과정에서 얻은 통찰력을 자연스럽게 포함한 정보 제공입니다.\n        '), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question', 'thinking'], input_types={}, partial_variables={}, template='\n        질문: {question}\n        추론: {thinking}\n        '), additional_kwargs={})]

# %%
#DeepSeek를 통해서 추론 부분까지만 생성합니다. 
def think(state: State):
    question = state["question"]
    response = reasoning_model.invoke(question)
    #print(response.content)
    return {"thinking": response.content}

#Qwen를 통해서 결과 출력 부분을 생성합니다.
def generate(state: State):
    messages = answer_prompt.invoke({"question": state["question"], "thinking": state["thinking"]})
    response = generation_model.invoke(messages)
    print(response.content)
    return {"answer": response.content}

# 그래프 컴파일
graph_builder = StateGraph(State).add_sequence([think, generate])
graph_builder.add_edge(START, "think")
graph = graph_builder.compile()

# 입력 데이터
inputs = {"question": "9.9와 9.11 중 무엇이 더 큰가요?"}

# invoke()를 사용하여 그래프 호출
result = graph.invoke(inputs)
print(result)

# 결과 출력
print("==> 생성된 답변: \n")
print(result["answer"])
# Out:
# <think>
# Okay, let's see. The user is asking which is bigger between 9.9 and 9.11. Hmm. Both numbers start with 9, so the whole numbers are equal. But the decimal parts matter here.
#
# Wait, 9.9 is the same as 9.90 when considering decimals. So comparing 9.90 and 9.11. Let's break it down digit by digit. The first digit after the decimal is 9 in the first number and 1 in the second. Since 9 is greater than 1, the first number is larger.
#
# So even though both have the same whole number, the decimal part determines the result. The key here is that when comparing decimals, we look at each digit starting from the left. The first differing digit decides which number is larger.
#
# Therefore, 9.9 is bigger than 9.11. I should make sure to explain that the whole numbers are equal, but the tenths place in 9.9 is higher than in 9.11. That's why 9.9 is larger.
#
# I need to present this in a clear, conversational way without using markdown. Make sure to highlight the important points: equal whole numbers, comparing the tenths place, and the result. Avoid technical jargon but keep it precise.
# </think>
#
# 9.9와 9.11 중 더 큰 수는 **9.9**입니다.
# 두 수는 모두 9를 가진다면, 소수점 아래의 숫자를 비교해야 합니다.
# 9.9는 9.90과 같이 표현하면 9.90, 9.11으로 바꾸고, 각 자리수를 비교해도 소수점 아래의 9가 1보다 더 커서 9.90이 더 클 것입니다.
# 따라서, 9.9는 9.11보다 더 큰 수입니다.
# {'question': '9.9와 9.11 중 무엇이 더 큰가요?', 'thinking': "<think>\nFirst, I need to compare the two numbers: 9.9 and 9.11.\n\nBoth numbers have the same whole number part, which is 9.\n\nTo make a fair comparison, I'll align them by adding an extra decimal place to 9.9, making it 9.90.\n\nNow, both numbers are 9.90 and 9.11.\n\nComparing each digit from left to right:\n\n- The whole number part is equal (both have 9).\n- In the tenths place, 9 in 9.90 is greater than 1 in 9.11.\n  \nSince 9.90 has a higher value in the tenths place, it is larger than 9.11.\n\nTherefore, 9.9 is greater than 9.11.\n", 'answer': "<think>\nOkay, let's see. The user is asking which is bigger between 9.9 and 9.11. Hmm. Both numbers start with 9, so the whole numbers are equal. But the decimal parts matter here. \n\nWait, 9.9 is the same as 9.90 when considering decimals. So comparing 9.90 and 9.11. Let's break it down digit by digit. The first digit after the decimal is 9 in the first number and 1 in the second. Since 9 is greater than 1, the first number is larger. \n\nSo even though both have the same whole number, the decimal part determines the result. The key here is that when comparing decimals, we look at each digit starting from the left. The first differing digit decides which number is larger. \n\nTherefore, 9.9 is bigger than 9.11. I should make sure to explain that the whole numbers are equal, but the tenths place in 9.9 is higher than in 9.11. That's why 9.9 is larger. \n\nI need to present this in a clear, conversational way without using markdown. Make sure to highlight the important points: equal whole numbers, comparing the tenths place, and the result. Avoid technical jargon but keep it precise.\n</think>\n\n9.9와 9.11 중 더 큰 수는 **9.9**입니다.  \n두 수는 모두 9를 가진다면, 소수점 아래의 숫자를 비교해야 합니다.  \n9.9는 9.90과 같이 표현하면 9.90, 9.11으로 바꾸고, 각 자리수를 비교해도 소수점 아래의 9가 1보다 더 커서 9.90이 더 클 것입니다.  \n따라서, 9.9는 9.11보다 더 큰 수입니다."}
# ==> 생성된 답변:
#
# <think>
# Okay, let's see. The user is asking which is bigger between 9.9 and 9.11. Hmm. Both numbers start with 9, so the whole numbers are equal. But the decimal parts matter here.
#
# Wait, 9.9 is the same as 9.90 when considering decimals. So comparing 9.90 and 9.11. Let's break it down digit by digit. The first digit after the decimal is 9 in the first number and 1 in the second. Since 9 is greater than 1, the first number is larger.
#
# So even though both have the same whole number, the decimal part determines the result. The key here is that when comparing decimals, we look at each digit starting from the left. The first differing digit decides which number is larger.
#
# Therefore, 9.9 is bigger than 9.11. I should make sure to explain that the whole numbers are equal, but the tenths place in 9.9 is higher than in 9.11. That's why 9.9 is larger.
#
# I need to present this in a clear, conversational way without using markdown. Make sure to highlight the important points: equal whole numbers, comparing the tenths place, and the result. Avoid technical jargon but keep it precise.
# </think>
#
# 9.9와 9.11 중 더 큰 수는 **9.9**입니다.
# 두 수는 모두 9를 가진다면, 소수점 아래의 숫자를 비교해야 합니다.
# 9.9는 9.90과 같이 표현하면 9.90, 9.11으로 바꾸고, 각 자리수를 비교해도 소수점 아래의 9가 1보다 더 커서 9.90이 더 클 것입니다.
# 따라서, 9.9는 9.11보다 더 큰 수입니다.

# %%
import os
os.environ["PYPPETEER_BROWSER_PATH"] = r"C:\Program Files\Google\Chrome\Application\chrome.exe"

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod
import nest_asyncio

# Jupyter 환경에서 asyncio 충돌 방지
nest_asyncio.apply()

# pyppeteer를 이용해 로컬에서 Mermaid 다이어그램 렌더링
png_bytes = graph.get_graph().draw_mermaid_png(draw_method=MermaidDrawMethod.PYPPETEER)

# 이미지 출력
display(Image(png_bytes))
# Out:
# [INFO] Starting Chromium download.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 9
#       6 nest_asyncio.apply()
#       8 # pyppeteer를 이용해 로컬에서 Mermaid 다이어그램 렌더링
# ----> 9 png_bytes = graph.get_graph().draw_mermaid_png(draw_method=MermaidDrawMethod.PYPPETEER)
#      11 # 이미지 출력
#      12 display(Image(png_bytes))
#
# File c:\Users\user\AppData\Local\pypoetry\Cache\virtualenvs\mylangchain-app-SBe-Yh6W-py3.12\Lib\site-packages\langchain_core\runnables\graph.py:702, in Graph.draw_mermaid_png(self, curve_style, node_colors, wrap_label_n_words, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, frontmatter_config)
#     692 from langchain_core.runnables.graph_mermaid import (  # noqa: PLC0415
#     693     draw_mermaid_png,
#     694 )
#     696 mermaid_syntax = self.draw_mermaid(
#     697     curve_style=curve_style,
#     698     node_colors=node_colors,
#     699     wrap_label_n_words=wrap_label_n_words,
#     700     frontmatter_config=frontmatter_config,
#     701 )
# --> 702 return draw_mermaid_png(
#     703     mermaid_syntax=mermaid_syntax,
#     704     output_file_path=output_file_path,
#     705     draw_method=draw_method,
#     706     background_color=background_color,
#     707     padding=padding,
#     708     max_retries=max_retries,
#     709     retry_delay=retry_delay,
#     710 )
#
# File c:\Users\user\AppData\Local\pypoetry\Cache\virtualenvs\mylangchain-app-SBe-Yh6W-py3.12\Lib\site-packages\langchain_core\runnables\graph_mermaid.py:304, in draw_mermaid_png(mermaid_syntax, output_file_path, draw_method, background_color, padding, max_retries, retry_delay)
#     281 """Draws a Mermaid graph as PNG using provided syntax.
#     282
#     283 Args:
#    (...)    301     ValueError: If an invalid draw method is provided.
#     302 """
#     303 if draw_method == MermaidDrawMethod.PYPPETEER:
# --> 304     img_bytes = asyncio.run(
#     305         _render_mermaid_using_pyppeteer(
#     306             mermaid_syntax, output_file_path, background_color, padding
#     307         )
#     308     )
#     309 elif draw_method == MermaidDrawMethod.API:
#     310     img_bytes = _render_mermaid_using_api(
#     311         mermaid_syntax,
#     312         output_file_path=output_file_path,
#    (...)    315         retry_delay=retry_delay,
#     316     )
#
# File c:\Users\user\AppData\Local\pypoetry\Cache\virtualenvs\mylangchain-app-SBe-Yh6W-py3.12\Lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File c:\Users\user\AppData\Local\pypoetry\Cache\virtualenvs\mylangchain-app-SBe-Yh6W-py3.12\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\anaconda3\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File ~\anaconda3\Lib\asyncio\tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# File c:\Users\user\AppData\Local\pypoetry\Cache\virtualenvs\mylangchain-app-SBe-Yh6W-py3.12\Lib\site-packages\langchain_core\runnables\graph_mermaid.py:340, in _render_mermaid_using_pyppeteer(mermaid_syntax, output_file_path, background_color, padding, device_scale_factor)
#     337     msg = "Install Pyppeteer to use the Pyppeteer method: `pip install pyppeteer`."
#     338     raise ImportError(msg)
# --> 340 browser = await launch()
#     341 page = await browser.newPage()
#     343 # Setup Mermaid JS
#
# File c:\Users\user\AppData\Local\pypoetry\Cache\virtualenvs\mylangchain-app-SBe-Yh6W-py3.12\Lib\site-packages\pyppeteer\launcher.py:307, in launch(options, **kwargs)
#     239 async def launch(options: dict = None, **kwargs: Any) -> Browser:
#     240     """Start chrome process and return :class:`~pyppeteer.browser.Browser`.
#     241     This function is a shortcut to :meth:`Launcher(options, **kwargs).launch`.
#     242     Available options are:
#    (...)    305         option with extreme caution.
#     306     """
# --> 307     return await Launcher(options, **kwargs).launch()
#
# File c:\Users\user\AppData\Local\pypoetry\Cache\virtualenvs\mylangchain-app-SBe-Yh6W-py3.12\Lib\site-packages\pyppeteer\launcher.py:120, in Launcher.__init__(self, options, **kwargs)
#     118 if not self.chromeExecutable:
#     119     if not check_chromium():
# --> 120         download_chromium()
#     121     self.chromeExecutable = str(chromium_executable())
#     123 self.cmd = [self.chromeExecutable] + self.chromeArguments
#
# File c:\Users\user\AppData\Local\pypoetry\Cache\virtualenvs\mylangchain-app-SBe-Yh6W-py3.12\Lib\site-packages\pyppeteer\chromium_downloader.py:138, in download_chromium()
#     136 def download_chromium() -> None:
#     137     """Download and extract chromium."""
# --> 138     extract_zip(download_zip(get_url()), DOWNLOADS_FOLDER / REVISION)
#
# File c:\Users\user\AppData\Local\pypoetry\Cache\virtualenvs\mylangchain-app-SBe-Yh6W-py3.12\Lib\site-packages\pyppeteer\chromium_downloader.py:82, in download_zip(url)
#      80 r = http.request('GET', url, preload_content=False)
#      81 if r.status >= 400:
# ---> 82     raise OSError(f'Chromium downloadable not found at {url}: ' f'Received {r.data.decode()}.\n')
#      84 # 10 * 1024
#      85 _data = BytesIO()
#
# OSError: Chromium downloadable not found at https://storage.googleapis.com/chromium-browser-snapshots/Win_x64/1181205/chrome-win.zip: Received <?xml version='1.0' encoding='UTF-8'?><Error><Code>NoSuchKey</Code><Message>The specified key does not exist.</Message><Details>No such object: chromium-browser-snapshots/Win_x64/1181205/chrome-win.zip</Details></Error>.

# %%
import os
import sys
from langchain_ollama import ChatOllama
from langgraph.graph import START, StateGraph
from typing_extensions import List, TypedDict
from langchain_core.prompts import ChatPromptTemplate

# UTF-8 인코딩 강제 설정 (Jupyter 노트북 호환)
os.environ['PYTHONIOENCODING'] = 'utf-8'
os.environ['LANG'] = 'ko_KR.UTF-8'
os.environ['LC_ALL'] = 'ko_KR.UTF-8'

# Jupyter 환경에서는 reconfigure 대신 환경변수로 처리
try:
    if hasattr(sys.stdout, 'reconfigure') and sys.stdout.encoding != 'utf-8':
        sys.stdout.reconfigure(encoding='utf-8')
except (AttributeError, OSError):
    # Jupyter 노트북이나 다른 환경에서는 패스
    pass

# 모델 초기화 - 한글 처리 개선
reasoning_model = ChatOllama(
    model="deepseek-r1:1.5b", 
    temperature=0, 
    stop=["</think>"]
)

generation_model = ChatOllama(
    model="qwen3:1.7b", 
    temperature=0.7
)

# LangGraph State 정의
class State(TypedDict):
    question: str
    thinking: str
    answer: str

# 개선된 프롬프트 템플릿
answer_prompt = ChatPromptTemplate([
    (
        "system",
        """당신은 한국어로 응답하는 AI 어시스턴트입니다. 
        반드시 한국어로만 답변하세요.
        
        당신의 작업:
        - 질문과 제공된 추론을 신중하게 분석하세요.
        - 추론에서 얻은 통찰력을 포함하여 잘 구조화된 한국어 답변을 생성하세요.
        - 답변이 사용자의 질문에 직접적으로 대응하도록 하세요.
        - 정보를 명확하고 자연스럽게 전달하되, 추론 과정을 명시적으로 언급하지 마세요.
        
        지침:
        - 답변을 대화 형식으로 작성하고, 흥미롭게 전달하세요.
        - 중요한 포인트를 모두 다루면서도 명확하고 간결하게 작성하세요.
        - 제공된 추론을 사용한다는 것을 언급하지 말고, 그 통찰력을 자연스럽게 포함시키세요.
        - 도움이 되고 전문적인 톤을 유지하세요.
        
        중요: 반드시 한국어로만 응답하세요."""
    ),
    (
        "human",
        """질문: {question}
        
        추론 과정: {thinking}
        
        위 내용을 바탕으로 한국어로 답변해주세요:"""
    )
])

def ensure_utf8_string(text):
    """문자열이 UTF-8로 제대로 인코딩되었는지 확인하고 변환"""
    if text is None:
        return ""
    if isinstance(text, bytes):
        return text.decode('utf-8', errors='ignore')
    return str(text)

# DeepSeek를 통해서 추론 부분까지만 생성
def think(state: State):
    question = state["question"]
    print(f"[DEBUG] 입력 질문: {question}")
    print(f"[DEBUG] 질문 타입: {type(question)}")
    
    response = reasoning_model.invoke(question)
    thinking_content = ensure_utf8_string(response.content)
    
    print(f"[DEBUG] 추론 결과 타입: {type(response.content)}")
    print(f"[DEBUG] 추론 결과 길이: {len(thinking_content)}")
    print(f"[DEBUG] 추론 결과 미리보기: {thinking_content[:200]}...")
    
    return {"thinking": thinking_content}

# qwen2.5를 통해서 결과 출력 부분을 생성
def generate(state: State):
    question = ensure_utf8_string(state["question"])
    thinking = ensure_utf8_string(state["thinking"])
    
    print(f"[DEBUG] generate 함수 - 질문: {question}")
    print(f"[DEBUG] generate 함수 - 추론 길이: {len(thinking)}")
    print(f"[DEBUG] generate 함수 - 추론 미리보기: {thinking[:200]}...")
    
    messages = answer_prompt.invoke({
        "question": question, 
        "thinking": thinking
    })
    
    print(f"[DEBUG] 프롬프트 메시지 생성 완료")
    
    response = generation_model.invoke(messages)
    answer_content = ensure_utf8_string(response.content)
    
    print(f"[DEBUG] 최종 응답 타입: {type(response.content)}")
    print(f"[DEBUG] 최종 응답 길이: {len(answer_content)}")
    print(f"[DEBUG] 최종 응답 내용: {answer_content}")
    
    return {"answer": answer_content}

# 그래프 구성 및 컴파일
graph_builder = StateGraph(State).add_sequence([think, generate])
graph_builder.add_edge(START, "think")
graph = graph_builder.compile()

def main():
    # 입력 데이터
    inputs = {"question": "9.9와 9.11 중 무엇이 더 큰가요?"}
    
    print("="*50)
    print("LangGraph 실행 시작")
    print("="*50)
    
    try:
        # invoke()를 사용하여 그래프 호출
        result = graph.invoke(inputs)
        
        print("="*50)
        print("실행 결과")
        print("="*50)
        print(f"전체 결과: {result}")
        print(f"최종 답변: {result.get('answer', '답변 없음')}")
        
    except Exception as e:
        print(f"오류 발생: {e}")
        import traceback
        traceback.print_exc()

if __name__ == "__main__":
    main()
# Out:
# ==================================================
# LangGraph 실행 시작
# ==================================================
# [DEBUG] 입력 질문: 9.9와 9.11 중 무엇이 더 큰가요?
# [DEBUG] 질문 타입: <class 'str'>
# [DEBUG] 추론 결과 타입: <class 'str'>
# [DEBUG] 추론 결과 길이: 529
# [DEBUG] 추론 결과 미리보기: <think>
# First, I need to compare the two numbers: 9.9 and 9.11.
#
# Both numbers have the same whole number part, which is 9.
#
# To make a fair comparison, I'll align them by adding an extra decimal place ...
# [DEBUG] generate 함수 - 질문: 9.9와 9.11 중 무엇이 더 큰가요?
# [DEBUG] generate 함수 - 추론 길이: 529
# [DEBUG] generate 함수 - 추론 미리보기: <think>
# First, I need to compare the two numbers: 9.9 and 9.11.
#
# Both numbers have the same whole number part, which is 9.
#
# To make a fair comparison, I'll align them by adding an extra decimal place ...
# [DEBUG] 프롬프트 메시지 생성 완료
# [DEBUG] 최종 응답 타입: <class 'str'>
# [DEBUG] 최종 응답 길이: 1865
# [DEBUG] 최종 응답 내용: <think>
# Okay, let's tackle this question. The user is asking which number is bigger between 9.9 and 9.11. Hmm, both numbers start with 9, so the whole numbers are the same. But the decimal parts matter here.
#
# First, I need to compare the tenths place. 9.9 has a 9 in the tenths place, while 9.11 has a 1. Since 9 is greater than 1, even though the ones place is the same, 9.9 is larger. Wait, but the user provided a process where they added a zero to make 9.90. That's a good point because it shows that 9.90 is actually 9.9, which is more than 9.11.
#
# So the key here is that even though the whole numbers are the same, the decimal part determines the value. The tenths place in 9.9 is 9, which is higher than the 1 in 9.11. Therefore, 9.9 is bigger. I should make sure to explain that the decimal part is what's important here, not the whole number. Also, mention that adding a zero to 9.9 makes it 9.90, which is the same as 9.9, and then compare it to 9.11.
#
# Wait, the user's process already did that. So in the answer, I need to present the conclusion without going into the process details. Just state that 9.9 is larger because the tenths place is higher. Make sure the answer is clear and direct, using the comparison of the decimal parts. Also, check if there's any other detail I missed, like whether there's a need to consider the hundredths place. But since 9.11 has a 1 in the hundredths place and 9.90 has a 0, the tenths place is already sufficient.
#
# So the final answer should be straightforward: 9.9 is larger than 9.11 because the tenths digit in 9.9 is 9, which is greater than 1 in 9.11. That's the main point. No need to mention the process, just the comparison.
# </think>
#
# 9.9는 9.11보다 더 큰 수입니다. 두 수의 정수 부분은 모두 9입니다. 하지만 소수 부분을 비교해야 합니다. 9.9는 9.90과 같으며, 9.11은 9.11입니다. 소수 점 다음의 첫 번째 자리 숫자로는 9(9.90)이 1(9.11)보다 더 높기 때문에, 9.9는 9.11보다 더 큰 수입니다.
# ==================================================
# 실행 결과
# ==================================================
# 전체 결과: {'question': '9.9와 9.11 중 무엇이 더 큰가요?', 'thinking': "<think>\nFirst, I need to compare the two numbers: 9.9 and 9.11.\n\nBoth numbers have the same whole number part, which is 9.\n\nTo make a fair comparison, I'll align them by adding an extra decimal place to 9.9, making it 9.90.\n\nNow, both numbers are 9.90 and 9.11.\n\nComparing each digit from left to right:\n\n- The whole number part is equal (both have 9).\n- In the tenths place, 9 in 9.90 is greater than 1 in 9.11.\n  \nSince 9.90 has a higher value in the tenths place, it is larger than 9.11.\n\nTherefore, 9.9 is greater than 9.11.\n", 'answer': "<think>\nOkay, let's tackle this question. The user is asking which number is bigger between 9.9 and 9.11. Hmm, both numbers start with 9, so the whole numbers are the same. But the decimal parts matter here. \n\nFirst, I need to compare the tenths place. 9.9 has a 9 in the tenths place, while 9.11 has a 1. Since 9 is greater than 1, even though the ones place is the same, 9.9 is larger. Wait, but the user provided a process where they added a zero to make 9.90. That's a good point because it shows that 9.90 is actually 9.9, which is more than 9.11. \n\nSo the key here is that even though the whole numbers are the same, the decimal part determines the value. The tenths place in 9.9 is 9, which is higher than the 1 in 9.11. Therefore, 9.9 is bigger. I should make sure to explain that the decimal part is what's important here, not the whole number. Also, mention that adding a zero to 9.9 makes it 9.90, which is the same as 9.9, and then compare it to 9.11. \n\nWait, the user's process already did that. So in the answer, I need to present the conclusion without going into the process details. Just state that 9.9 is larger because the tenths place is higher. Make sure the answer is clear and direct, using the comparison of the decimal parts. Also, check if there's any other detail I missed, like whether there's a need to consider the hundredths place. But since 9.11 has a 1 in the hundredths place and 9.90 has a 0, the tenths place is already sufficient. \n\nSo the final answer should be straightforward: 9.9 is larger than 9.11 because the tenths digit in 9.9 is 9, which is greater than 1 in 9.11. That's the main point. No need to mention the process, just the comparison.\n</think>\n\n9.9는 9.11보다 더 큰 수입니다. 두 수의 정수 부분은 모두 9입니다. 하지만 소수 부분을 비교해야 합니다. 9.9는 9.90과 같으며, 9.11은 9.11입니다. 소수 점 다음의 첫 번째 자리 숫자로는 9(9.90)이 1(9.11)보다 더 높기 때문에, 9.9는 9.11보다 더 큰 수입니다."}
# 최종 답변: <think>
# Okay, let's tackle this question. The user is asking which number is bigger between 9.9 and 9.11. Hmm, both numbers start with 9, so the whole numbers are the same. But the decimal parts matter here.
#
# First, I need to compare the tenths place. 9.9 has a 9 in the tenths place, while 9.11 has a 1. Since 9 is greater than 1, even though the ones place is the same, 9.9 is larger. Wait, but the user provided a process where they added a zero to make 9.90. That's a good point because it shows that 9.90 is actually 9.9, which is more than 9.11.
#
# So the key here is that even though the whole numbers are the same, the decimal part determines the value. The tenths place in 9.9 is 9, which is higher than the 1 in 9.11. Therefore, 9.9 is bigger. I should make sure to explain that the decimal part is what's important here, not the whole number. Also, mention that adding a zero to 9.9 makes it 9.90, which is the same as 9.9, and then compare it to 9.11.
#
# Wait, the user's process already did that. So in the answer, I need to present the conclusion without going into the process details. Just state that 9.9 is larger because the tenths place is higher. Make sure the answer is clear and direct, using the comparison of the decimal parts. Also, check if there's any other detail I missed, like whether there's a need to consider the hundredths place. But since 9.11 has a 1 in the hundredths place and 9.90 has a 0, the tenths place is already sufficient.
#
# So the final answer should be straightforward: 9.9 is larger than 9.11 because the tenths digit in 9.9 is 9, which is greater than 1 in 9.11. That's the main point. No need to mention the process, just the comparison.
# </think>
#
# 9.9는 9.11보다 더 큰 수입니다. 두 수의 정수 부분은 모두 9입니다. 하지만 소수 부분을 비교해야 합니다. 9.9는 9.90과 같으며, 9.11은 9.11입니다. 소수 점 다음의 첫 번째 자리 숫자로는 9(9.90)이 1(9.11)보다 더 높기 때문에, 9.9는 9.11보다 더 큰 수입니다.

# %%
inputs = {"question": "9.9와 9.11 중 무엇이 더 큰가요?"}

async for event in graph.astream_events(inputs, version="v2"):
    kind = event["event"]
    if kind == "on_chat_model_stream":
        print(event['data']['chunk'].content, end="", flush=True)

# %%
import gradio as gr
import os
import sys
from langchain_ollama import ChatOllama
from langgraph.graph import START, StateGraph
from typing_extensions import List, TypedDict
from langchain_core.prompts import ChatPromptTemplate

# UTF-8 인코딩 강제 설정 (Jupyter 노트북 호환)
os.environ['PYTHONIOENCODING'] = 'utf-8'
os.environ['LANG'] = 'ko_KR.UTF-8'
os.environ['LC_ALL'] = 'ko_KR.UTF-8'

# Jupyter 환경에서는 reconfigure 대신 환경변수로 처리
try:
    if hasattr(sys.stdout, 'reconfigure') and sys.stdout.encoding != 'utf-8':
        sys.stdout.reconfigure(encoding='utf-8')
except (AttributeError, OSError):
    # Jupyter 노트북이나 다른 환경에서는 패스
    pass

# 모델 설정: 두 개의 서로 다른 모델을 사용하여 추론과 답변 생성을 수행
# - reasoning_model: 추론을 담당하는 모델 (온도 낮음, 정확한 분석용)
# - generation_model: 답변 생성을 담당하는 모델 (온도 높음, 창의적 응답용)
reasoning_model = ChatOllama(
    model="deepseek-r1:1.5b", 
    temperature=0, 
    stop=["</think>"]
)

generation_model = ChatOllama(
    model="qwen3:1.7b", 
    temperature=0.7
)

# 상태(State) 정의: 그래프에서 상태를 유지하기 위한 데이터 구조
class State(TypedDict):
    question: str   # 사용자의 질문
    thinking: str   # 추론 결과
    answer: str     # 최종 답변

# 개선된 프롬프트 템플릿
answer_prompt = ChatPromptTemplate([
    (
        "system",
        """당신은 한국어로 응답하는 AI 어시스턴트입니다. 
        반드시 한국어로만 답변하세요.
        
        당신의 작업:
        - 질문과 제공된 추론을 신중하게 분석하세요.
        - 추론에서 얻은 통찰력을 포함하여 잘 구조화된 한국어 답변을 생성하세요.
        - 답변이 사용자의 질문에 직접적으로 대응하도록 하세요.
        - 정보를 명확하고 자연스럽게 전달하되, 추론 과정을 명시적으로 언급하지 마세요.
        
        지침:
        - 답변을 대화 형식으로 작성하고, 흥미롭게 전달하세요.
        - 중요한 포인트를 모두 다루면서도 명확하고 간결하게 작성하세요.
        - 제공된 추론을 사용한다는 것을 언급하지 말고, 그 통찰력을 자연스럽게 포함시키세요.
        - 도움이 되고 전문적인 톤을 유지하세요.
        
        중요: 반드시 한국어로만 응답하세요."""
    ),
    (
        "human",
        """질문: {question}
        
        추론 과정: {thinking}
        
        위 내용을 바탕으로 한국어로 답변해주세요:"""
    )
])


def ensure_utf8_string(text):
    """문자열이 UTF-8로 제대로 인코딩되었는지 확인하고 변환"""
    if text is None:
        return ""
    if isinstance(text, bytes):
        try:
            return text.decode('utf-8')
        except UnicodeDecodeError:
            return text.decode('utf-8', errors='ignore')
    
    # 문자열이지만 인코딩 문제가 있을 수 있는 경우 처리
    if isinstance(text, str):
        try:
            # 문자열을 UTF-8로 인코딩했다가 다시 디코딩하여 정리
            return text.encode('utf-8').decode('utf-8')
        except (UnicodeEncodeError, UnicodeDecodeError):
            return text
    
    return str(text)

# DeepSeek를 통해서 추론 부분까지만 생성
def think(state: State):
    question = state["question"]
    print(f"[DEBUG] 입력 질문: {question}")
    print(f"[DEBUG] 질문 타입: {type(question)}")
    
    response = reasoning_model.invoke(question)
    thinking_content = ensure_utf8_string(response.content)
    
    print(f"[DEBUG] 추론 결과 타입: {type(response.content)}")
    print(f"[DEBUG] 추론 결과 길이: {len(thinking_content)}")
    print(f"[DEBUG] 추론 결과 미리보기: {thinking_content[:200]}...")
    
    return {"thinking": thinking_content}

# qwen2.5를 통해서 결과 출력 부분을 생성
def generate(state: State):
    question = ensure_utf8_string(state["question"])
    thinking = ensure_utf8_string(state["thinking"])
    
    print(f"[DEBUG] generate 함수 - 질문: {question}")
    print(f"[DEBUG] generate 함수 - 추론 길이: {len(thinking)}")
    print(f"[DEBUG] generate 함수 - 추론 미리보기: {thinking[:200]}...")
    
    messages = answer_prompt.invoke({
        "question": question, 
        "thinking": thinking
    })
    
    print(f"[DEBUG] 프롬프트 메시지 생성 완료")
    
    response = generation_model.invoke(messages)
    answer_content = ensure_utf8_string(response.content)
    
    print(f"[DEBUG] 최종 응답 타입: {type(response.content)}")
    print(f"[DEBUG] 최종 응답 길이: {len(answer_content)}")
    print(f"[DEBUG] 최종 응답 내용: {answer_content}")
    
    return {"answer": answer_content}

# 그래프 생성 함수: 상태(State) 간의 흐름을 정의
def create_graph():
    graph_builder = StateGraph(State).add_sequence([think, generate])
    graph_builder.add_edge(START, "think")
    return graph_builder.compile()

# Gradio 인터페이스 생성 및 실행
def chatbot_interface(message, history):
    graph = create_graph()
    inputs = {"question": message}
    result = graph.invoke(inputs)
    return result["answer"]

#iface = gr.ChatInterface(fn=chatbot_interface, title="AI 챗봇", description="질문을 입력하면 AI가 답변을 제공합니다.")

# Gradio 인터페이스 설정
def launch_gradio():
    #iface = gr.Interface(fn=chatbot_interface, inputs="text", outputs="text", title="AI 챗봇", description="질문을 입력하면 AI가 답변을 제공합니다.")
    iface = gr.ChatInterface(fn=chatbot_interface, title="AI 챗봇", description="질문을 입력하면 AI가 답변을 제공합니다.")
    iface.launch()

if __name__ == "__main__":
    #iface.launch()
    launch_gradio()
# Out:
# c:\Users\user\AppData\Local\pypoetry\Cache\virtualenvs\mylangchain-app-SBe-Yh6W-py3.12\Lib\site-packages\gradio\chat_interface.py:348: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   self.chatbot = Chatbot(
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# [DEBUG] 입력 질문: ㄴㅇㅁㅁㄴㅇ
# [DEBUG] 질문 타입: <class 'str'>
# [DEBUG] 입력 질문: 파이썬이란?
# [DEBUG] 질문 타입: <class 'str'>
# [DEBUG] 입력 질문: 파이썬이란?
# [DEBUG] 질문 타입: <class 'str'>
# [DEBUG] 입력 질문:
# What is Python?
# [DEBUG] 질문 타입: <class 'str'>
# [DEBUG] 추론 결과 타입: <class 'str'>
# [DEBUG] 추론 결과 길이: 88556
# [DEBUG] 추론 결과 미리보기: 0.5 kg of a solution with concentration c is mixed with 0.3 kg of another solution with concentration d, resulting in a final solution with concentration e. If the mass of the solutions are proportion...
# [DEBUG] generate 함수 - 질문: ㄴㅇㅁㅁㄴㅇ
# [DEBUG] generate 함수 - 추론 길이: 88556
# [DEBUG] generate 함수 - 추론 미리보기: 0.5 kg of a solution with concentration c is mixed with 0.3 kg of another solution with concentration d, resulting in a final solution with concentration e. If the mass of the solutions are proportion...
# [DEBUG] 프롬프트 메시지 생성 완료
# [DEBUG] 추론 결과 타입: <class 'str'>
# [DEBUG] 추론 결과 길이: 9
# [DEBUG] 추론 결과 미리보기: <think>
#
# ...
# [DEBUG] generate 함수 - 질문: 파이썬이란?
# [DEBUG] generate 함수 - 추론 길이: 9
# [DEBUG] generate 함수 - 추론 미리보기: <think>
#
# ...
# [DEBUG] 프롬프트 메시지 생성 완료
# [DEBUG] 추론 결과 타입: <class 'str'>
# [DEBUG] 추론 결과 길이: 9
# [DEBUG] 추론 결과 미리보기: <think>
#
# ...
# [DEBUG] generate 함수 - 질문: 파이썬이란?
# [DEBUG] generate 함수 - 추론 길이: 9
# [DEBUG] generate 함수 - 추론 미리보기: <think>
#
# ...
# [DEBUG] 프롬프트 메시지 생성 완료
# [DEBUG] 추론 결과 타입: <class 'str'>
# [DEBUG] 추론 결과 길이: 9
# [DEBUG] 추론 결과 미리보기: <think>
#
# ...
# [DEBUG] generate 함수 - 질문:
# What is Python?
# [DEBUG] generate 함수 - 추론 길이: 9
# [DEBUG] generate 함수 - 추론 미리보기: <think>
#
# ...
# [DEBUG] 프롬프트 메시지 생성 완료
# [DEBUG] 최종 응답 타입: <class 'str'>
# [DEBUG] 최종 응답 길이: 2524
# [DEBUG] 최종 응답 내용: <think>
# Okay, let's see. The user provided a problem about finding the ratio of (e - c)/(d - e) given certain conditions. They mentioned that m1 + m2 = 0.8 kg, and from the proportional masses, d = 0.6c. Then they calculated e as 0.85c. The final ratio is 0.6, which is 3/5 or 3:5.
#
# First, I need to make sure I understand the problem correctly. The question is about finding the ratio (e - c)/(d - e) where e is the concentration of a substance in a mixture, and c and d are concentrations from two different sources. The given information is that the total mass is 0.8 kg, and the ratio of the masses is 0.5/c = 0.3/d, leading to d = 0.6c. Then, substituting d into the expression for e, they found e = 0.85c.
#
# So, the ratio (e - c)/(d - e) becomes (0.85c - c)/(0.6c - 0.85c) = (-0.15c)/(-0.25c) = 0.6, which simplifies to 3/5 or 3:5.
#
# I need to check if there's any step where I might have made a mistake. Let me verify the calculations again.
#
# The key steps are:
# 1. From the proportional masses, 0.5/c = 0.3/d, solving for d gives d = (0.3/0.5)c = 0.6c. That seems correct.
# 2. Then, the final concentration e is calculated as (c² + d²)/(c + d). Plugging d = 0.6c, we get e = (c² + (0.6c)^2)/(c + 0.6c) = (1.36c²)/(1.6c) = 0.85c. That's correct.
# 3. Then, the ratio (e - c)/(d - e) is (0.85c - c)/(0.6c - 0.85c) = (-0.15c)/(-0.25c) = 0.6.
#
# Yes, that's correct. So the final answer is 0.6, which is 3/5 or 3:5.
#
# I should present the answer in the required format, which is a box with the simplified ratio. The user might be looking for the answer in fractions, so 3/5 or 3:5. Since the question says "3:5" in the previous example, I'll go with 3:5.
# </think>
#
# 질문에 따르면, 두 물질의 농도 $ c $와 $ d $가 주어졌을 때, 혼합된 물질의 농도 $ e $를 계산하고 비율 $(e - c)/(d - e)$를 구하는 문제입니다. 주어진 정보는 다음과 같습니다:
#
# 1. $ \frac{0.5}{c} = \frac{0.3}{d} $ → $ d = 0.6c $
# 2. $ m_1 + m_2 = 0.8 $kg (물질의 총 질량)
# 3. $ e = \frac{m_1 c + m_2 d}{m_1 + m_2} $
#
# **계산 과정:**
# - $ d = 0.6c $
# - $ e = \frac{m_1 c + m_2 d}{m_1 + m_2} $
# - $ m_1 + m_2 = 0.8 $kg, $ m_1 = k $, $ m_2 = 0.8 - k $
# - $ e = \frac{k c + (0.8 - k) \cdot 0.6c}{0.8} = \frac{0.8c + 0.6c - 0.6k c}{0.8} $
# - $ e = \frac{1.4c - 0.6k c}{0.8} $
# - $ k = \frac{0.8}{1.4} \cdot c $ (물질의 비율 계산)
# - $ e = \frac{1.4c - 0.6 \cdot \frac{0.8}{1.4} c^2}{0.8} $
# - 계산 후 $ e = 0.85c $
#
# **비율 계산:**
# - $ (e - c) = 0.85c - c = -0.15c $
# - $ (d - e) = 0.6c - 0.85c = -0.25c $
# - 비율: $ \frac{-0.15c}{-0.25c} = 0.6 = \frac{3}{5} $
#
# **최종 답:**
# $$
# \boxed{\dfrac{3}{5}} \quad \text{또는} \quad \boxed{3:5}
# $$
# [DEBUG] 최종 응답 타입: <class 'str'>
# [DEBUG] 최종 응답 길이: 1212
# [DEBUG] 최종 응답 내용: <think>
# Okay, let's tackle this question. The user is asking, "What is Python?" and the provided inference is about the history and features of Python.
#
# First, I need to make sure I understand the key points from the inference. Python was created by Guido van Rossum in 1991. It's a general-purpose programming language known for its readability and simplicity. The inference also mentions that Python is used in various fields like web development, data analysis, and automation. It's open-source and has a large community, which contributes to its popularity.
#
# Now, I need to structure the answer in a natural, conversational way without explicitly mentioning the inference. I should highlight the main points: origin, features, use cases, and community. Make sure the response is clear and directly answers the question. Avoid technical jargon but keep it informative. Also, keep the tone professional yet approachable. Let me put that together.
# </think>
#
# 파이썬은 고급스러운 코드의 읽기와 작성이 쉬운 언어로, 프로그래밍을 시작하는 사람들에게 편리한 도구가 되었어요. 1991년 Guido van Rossum이 만든 파이썬은 간결하고 명확한 문법을 특징으로, 웹 개발, 데이터 분석, 자동화, 인터넷 서비스 등 다양한 분야에서 널리 사용되고 있죠. 또한 오픈소스로 무료로 사용할 수 있어 패키지 관리와 커스터마이징이 용이하다고 합니다. 파이썬은 기술과 함께 성장하며, 프로그래머들의 마음을 사로잡고 있어요.
# [DEBUG] 최종 응답 타입: <class 'str'>
# [DEBUG] 최종 응답 길이: 1166
# [DEBUG] 최종 응답 내용: <think>
# Okay, let's tackle this question. The user is asking what Python is. The provided inference process is just a simple statement that Python is a programming language. But I need to create a more detailed answer based on that.
#
# First, I should explain that Python is a high-level, general-purpose programming language. It's known for its readability and simplicity. Mentioning that it was created by Guido van Rossum in 1991 makes it more specific. Then, highlight its use cases like web development, data analysis, scientific computing, and automation. Also, note its extensive libraries and frameworks, like Django and NumPy. Maybe mention the "Pythonic" style and how it's popular in the tech industry. Keep it concise but informative. Avoid any markdown and make sure the response is natural and conversational.
# </think>
#
# 파이썬은 명령어와 코드를 작성해 프로그램을 만들 수 있는 고유한 언어입니다. 이 언어는 간결하고 명확한 문법으로 인해 개발자들이 쉽게 코드를 작성할 수 있어 주로 웹 개발, 데이터 분석, 사이냅스 계산, 자동화 작업 등 다양한 분야에서 활용됩니다. 파이썬은 1991년에 지도 van Rossum이 개발한 것으로, 현재 세계적으로 널리 사용되고 있습니다. 특히 데이터 분석과 사이냅스 계산에 특화된 라이브러리들이 많아, 엔지니어링과 연구 분야에서 중요한 역할을 합니다. 파이썬은 코드의 가독성을 강조하며 "Pythonic" 스타일을 추구해, 프로그래밍 작업을 편하게 진행할 수 있도록 설계되었습니다.
# [DEBUG] 최종 응답 타입: <class 'str'>
# [DEBUG] 최종 응답 길이: 1572
# [DEBUG] 최종 응답 내용: <think>
# Okay, let's see. The user asked, "What is Python?" and the provided inference is... Well, the inference is empty. Hmm, that's a problem. The user expects an answer based on the inference given. But since the inference is blank, I need to figure out how to proceed.
#
# First, I should recall what Python is. Python is a programming language created by Guido van Rossum in 1991. It's known for being easy to read and write, with a focus on code clarity. It's widely used in web development, data analysis, artificial intelligence, and more. Features like dynamic typing, garbage collection, and a large standard library make it versatile.
#
# Since the inference was empty, maybe the user provided a blank response, and I need to generate the answer based on my knowledge. The task is to create a structured, natural Korean answer without mentioning the inference process. So I should outline the key points about Python: its creator, creation year, features, uses, and popularity.
#
# I need to make sure the answer is concise, covers the main aspects, and is in Korean. Avoid technical jargon but still be accurate. Also, the answer should directly address the user's question without any extra information. Let me structure it with an introduction, key features, applications, and a conclusion.
# </think>
#
# Python은 프로그래밍 언어로, Guido van Rossum이 1991년에 개발한 언어입니다. 코드는 간결하고 명확하며, 동적 타입과 자동 메모리 수집 기능을 갖추고 있습니다. 주요 특징으로는 빠른 실행 속도, 쉬운 익명 함수, 넓은 표준 라이브러리 등이 있습니다. 주로 웹 개발, 데이터 분석, 인공지능, 라이브러리 개발 등 다양한 분야에서 활용됩니다. Python은 프로그래밍 언어 중에서도 흔히 사용되는 언어로, 코드를 읽고 작성하는 데 있어 편리한 점이 특징입니다.
